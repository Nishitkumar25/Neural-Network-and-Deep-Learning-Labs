# %%
import keras,os
from keras.datasets import fashion_mnist, cifar100
from keras.layers import Dense, Activation, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization
from keras.models import Sequential
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import cv2
from keras import optimizers
from tensorflow.keras.layers import Lambda
from keras import backend as K
from sklearn import datasets # load dataset
from sklearn.model_selection import train_test_split # split dataset
from sklearn.preprocessing import StandardScaler # standard scaler
from sklearn.metrics import accuracy_score # check accuracy

# %%
(train_X,train_Y), (test_X,test_Y) = fashion_mnist.load_data()
train_X = train_X.reshape(-1, 28,28, 1)
test_X = test_X.reshape(-1, 28,28, 1)
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X / 255
test_X = test_X / 255
train_X1 = train_X[0:100]
train_Y1 = train_Y[:100]
val_X = train_X[100:150]
val_Y_Onehot = to_categorical(train_Y[100:150])
train_Y_one_hot = to_categorical(train_Y1)
test_Y_one_hot = to_categorical(test_Y)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model = Sequential()
model.add(Conv2D(64, (3,3), input_shape=(28, 28, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(64))
model.add(Dense(10))
model.add(Activation('softmax'))
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adam(),metrics=['accuracy'])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 26, 26, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 11, 11, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1600)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │         102,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             650 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_2 (Activation)            │ (None, 10)                  │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 140,682 (549.54 KB)
#  Trainable params: 140,682 (549.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_X1, train_Y_one_hot, batch_size=64, epochs=100, validation_data=(val_X,val_Y_Onehot))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.show()
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - accuracy: 0.0890 - loss: 2.2860 - val_accuracy: 0.0800 - val_loss: 2.2695
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.1996 - loss: 2.1418 - val_accuracy: 0.1000 - val_loss: 2.2428
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2344 - loss: 2.0019 - val_accuracy: 0.3200 - val_loss: 2.1280
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4473 - loss: 1.8322 - val_accuracy: 0.4800 - val_loss: 1.9269
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.6083 - loss: 1.6219 - val_accuracy: 0.6400 - val_loss: 1.6602
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6787 - loss: 1.3885 - val_accuracy: 0.6200 - val_loss: 1.4151
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7010 - loss: 1.1581 - val_accuracy: 0.6000 - val_loss: 1.2181
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7433 - loss: 0.9588 - val_accuracy: 0.6000 - val_loss: 1.0280
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7529 - loss: 0.8008 - val_accuracy: 0.6800 - val_loss: 0.8182
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8346 - loss: 0.6817 - val_accuracy: 0.7600 - val_loss: 0.7631
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8383 - loss: 0.5954 - val_accuracy: 0.7000 - val_loss: 0.7613
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8531 - loss: 0.5095 - val_accuracy: 0.7000 - val_loss: 0.7340
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8190 - loss: 0.4713 - val_accuracy: 0.7400 - val_loss: 0.7328
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8079 - loss: 0.4601 - val_accuracy: 0.7200 - val_loss: 0.7373
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8583 - loss: 0.3772 - val_accuracy: 0.6800 - val_loss: 0.8281
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8375 - loss: 0.4854 - val_accuracy: 0.7200 - val_loss: 0.6591
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8769 - loss: 0.3199 - val_accuracy: 0.7800 - val_loss: 0.6566
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.8783 - loss: 0.2861 - val_accuracy: 0.7600 - val_loss: 0.6217
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8969 - loss: 0.2750 - val_accuracy: 0.7400 - val_loss: 0.5644
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9050 - loss: 0.2442 - val_accuracy: 0.7600 - val_loss: 0.5933
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9073 - loss: 0.2387 - val_accuracy: 0.8000 - val_loss: 0.5610
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9392 - loss: 0.2026 - val_accuracy: 0.7600 - val_loss: 0.5875
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9510 - loss: 0.2100 - val_accuracy: 0.7400 - val_loss: 0.5526
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.9525 - loss: 0.1925 - val_accuracy: 0.7600 - val_loss: 0.5170
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9577 - loss: 0.1631 - val_accuracy: 0.7800 - val_loss: 0.5346
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.9615 - loss: 0.1464 - val_accuracy: 0.8400 - val_loss: 0.4941
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7800 - val_loss: 0.8379
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.7800 - val_loss: 0.8254
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7800 - val_loss: 0.8153
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.7800 - val_loss: 0.8194
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7800 - val_loss: 0.8329
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.7800 - val_loss: 0.8466
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.7800 - val_loss: 0.8440
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.7800 - val_loss: 0.8427
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7800 - val_loss: 0.8393
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.7800 - val_loss: 0.8448
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7800 - val_loss: 0.8564
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.7800 - val_loss: 0.8744
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.7800 - val_loss: 0.8908
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.7800 - val_loss: 0.8976

# %%
score = model.evaluate(test_X[0:100],test_Y_one_hot[0:100], verbose=1)
print('\nKeras CNN binary accuracy:', score[1],'\n')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6899 - loss: 2.2491
#
# Keras CNN binary accuracy: 0.6700000166893005

# %%
filters, biases = model.layers[0].get_weights()
for i in range(5):
    plt.imshow(filters[:,:,0,i], cmap='gray')
    plt.show()

# %%
from scipy import signal

filt = np.array([
    [[-1, -1, -1],
     [-1,  8, -1],
     [-1, -1, -1]]
])

im = train_X[10]


plt.imshow(im, cmap='gray')
plt.show()


ot = signal.convolve2d(im.reshape(28, 28), filt[0], boundary='symm', mode='same')

plt.imshow(ot, cmap='gray')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.ndimage import gaussian_filter, sobel
import cv2  # OpenCV for Canny edge detection
from skimage.filters import gabor  # Gabor filter

# Load Fashion-MNIST
from tensorflow.keras.datasets import fashion_mnist
(train_images, train_labels), (_, _) = fashion_mnist.load_data()

# Select an image
im = train_images[10]

# Show original image
plt.figure(figsize=(10, 10))
plt.subplot(3, 3, 1)
plt.imshow(im, cmap='gray')
plt.title("Original Image")
plt.axis("off")

# 1. **Laplacian Filter**
laplacian_filter = np.array([
    [-1, -1, -1],
    [-1,  8, -1],
    [-1, -1, -1]
])
laplacian_output = signal.convolve2d(im, laplacian_filter, boundary='symm', mode='same')

plt.subplot(3, 3, 2)
plt.imshow(laplacian_output, cmap='gray')
plt.title("Laplacian Filter")
plt.axis("off")

# 2. **Gabor Filter**
gabor_output, _ = gabor(im, frequency=0.2)

plt.subplot(3, 3, 3)
plt.imshow(gabor_output, cmap='gray')
plt.title("Gabor Filter")
plt.axis("off")

# 3. **Canny Edge Detection**
canny_output = cv2.Canny(im, 50, 150)  # Low and high threshold

plt.subplot(3, 3, 4)
plt.imshow(canny_output, cmap='gray')
plt.title("Canny Edge Detection")
plt.axis("off")

# 4. **Sobel Edge Detection (X-direction)**
sobel_x = sobel(im, axis=0)

plt.subplot(3, 3, 5)
plt.imshow(sobel_x, cmap='gray')
plt.title("Sobel X")
plt.axis("off")

# 5. **Sobel Edge Detection (Y-direction)**
sobel_y = sobel(im, axis=1)

plt.subplot(3, 3, 6)
plt.imshow(sobel_y, cmap='gray')
plt.title("Sobel Y")
plt.axis("off")

# 6. **Gaussian Blur (Smooth image)**
gaussian_blur = gaussian_filter(im, sigma=1)

plt.subplot(3, 3, 7)
plt.imshow(gaussian_blur, cmap='gray')
plt.title("Gaussian Blur")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
# Convert labels to one-hot encoding
train_Y_one_hot = to_categorical(train_Y1)
test_Y_one_hot = to_categorical(test_Y)

#  Build Fully Connected Dense Network
model = Sequential([
    Flatten(input_shape=(28, 28, 1)),  # Convert 28x28 image to 1D
    Dense(128, activation='relu'),
    Dropout(0.3),  # Regularization to prevent overfitting
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(10, activation='softmax')  # 10 classes (output layer)
])

# Compile Model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

#  Train Model
history = model.fit(train_X1, train_Y_one_hot,
                    validation_data=(val_X, val_Y_Onehot),
                    epochs=50, batch_size=16, verbose=1)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.1229 - loss: 2.4199 - val_accuracy: 0.2800 - val_loss: 2.0479
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.2834 - loss: 1.9838 - val_accuracy: 0.3200 - val_loss: 1.8798
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3781 - loss: 1.8353 - val_accuracy: 0.4400 - val_loss: 1.6884
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4445 - loss: 1.6481 - val_accuracy: 0.5000 - val_loss: 1.4686
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3293 - loss: 1.7030 - val_accuracy: 0.5800 - val_loss: 1.3189
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5416 - loss: 1.3609 - val_accuracy: 0.5200 - val_loss: 1.2363
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5444 - loss: 1.3014 - val_accuracy: 0.6200 - val_loss: 1.1303
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5734 - loss: 1.2055 - val_accuracy: 0.6000 - val_loss: 1.0424
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6350 - loss: 1.1066 - val_accuracy: 0.5600 - val_loss: 0.9984
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6769 - loss: 1.0076 - val_accuracy: 0.7200 - val_loss: 0.9598
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7185 - loss: 0.8807 - val_accuracy: 0.6800 - val_loss: 0.9235
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6418 - loss: 1.0009 - val_accuracy: 0.7600 - val_loss: 0.8301
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7663 - loss: 0.7928 - val_accuracy: 0.6200 - val_loss: 0.8388
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7846 - loss: 0.7158 - val_accuracy: 0.7000 - val_loss: 0.8361
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7663 - loss: 0.6604 - val_accuracy: 0.7000 - val_loss: 0.8027
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7907 - loss: 0.7466 - val_accuracy: 0.7200 - val_loss: 0.7379
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6870 - loss: 0.8166 - val_accuracy: 0.6800 - val_loss: 0.7807
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7989 - loss: 0.6224 - val_accuracy: 0.7200 - val_loss: 0.7744
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8081 - loss: 0.5673 - val_accuracy: 0.7600 - val_loss: 0.6761
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9041 - loss: 0.4775 - val_accuracy: 0.7800 - val_loss: 0.6420
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8028 - loss: 0.5761 - val_accuracy: 0.7600 - val_loss: 0.6408
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8546 - loss: 0.4572 - val_accuracy: 0.7800 - val_loss: 0.6302
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8453 - loss: 0.5073 - val_accuracy: 0.7800 - val_loss: 0.6707
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8672 - loss: 0.4506 - val_accuracy: 0.7600 - val_loss: 0.7130
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8895 - loss: 0.5084 - val_accuracy: 0.7800 - val_loss: 0.6522
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9040 - loss: 0.3812 - val_accuracy: 0.8000 - val_loss: 0.5829
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8894 - loss: 0.3876 - val_accuracy: 0.7400 - val_loss: 0.5779
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8961 - loss: 0.3603 - val_accuracy: 0.8200 - val_loss: 0.5786
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8671 - loss: 0.4355 - val_accuracy: 0.8200 - val_loss: 0.5432
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9045 - loss: 0.3635 - val_accuracy: 0.7400 - val_loss: 0.5708
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8885 - loss: 0.3803 - val_accuracy: 0.7400 - val_loss: 0.6066
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9276 - loss: 0.2695 - val_accuracy: 0.7000 - val_loss: 0.5892
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8226 - loss: 0.3618 - val_accuracy: 0.7800 - val_loss: 0.5823
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9404 - loss: 0.2666 - val_accuracy: 0.7600 - val_loss: 0.6065
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9522 - loss: 0.2744 - val_accuracy: 0.7600 - val_loss: 0.5902
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9274 - loss: 0.2946 - val_accuracy: 0.7800 - val_loss: 0.5457
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9554 - loss: 0.2386 - val_accuracy: 0.8000 - val_loss: 0.5601
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9395 - loss: 0.2688 - val_accuracy: 0.8000 - val_loss: 0.5906
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9235 - loss: 0.2902 - val_accuracy: 0.7600 - val_loss: 0.5689
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9375 - loss: 0.2148 - val_accuracy: 0.8000 - val_loss: 0.5203
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9886 - loss: 0.1701 - val_accuracy: 0.8200 - val_loss: 0.4994
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9370 - loss: 0.2314 - val_accuracy: 0.8400 - val_loss: 0.4988
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8951 - loss: 0.2697 - val_accuracy: 0.8400 - val_loss: 0.5139
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9195 - loss: 0.3265 - val_accuracy: 0.8200 - val_loss: 0.5063
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9595 - loss: 0.2007 - val_accuracy: 0.6600 - val_loss: 0.6819
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9059 - loss: 0.2804 - val_accuracy: 0.7200 - val_loss: 0.6935
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9032 - loss: 0.2534 - val_accuracy: 0.7800 - val_loss: 0.6149
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9501 - loss: 0.1542 - val_accuracy: 0.7800 - val_loss: 0.6042
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9832 - loss: 0.1628 - val_accuracy: 0.7800 - val_loss: 0.6520
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9617 - loss: 0.1283 - val_accuracy: 0.7600 - val_loss: 0.6283

# %%
# Plot Training vs Validation Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

# %%
#Test Model on Test Set
test_loss, test_acc = model.evaluate(test_X, test_Y_one_hot, verbose=1)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6670 - loss: 1.1331
# Test Accuracy: 0.6679

# %%
# Import necessary libraries
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets import fashion_mnist
from torch.utils.data import Dataset, DataLoader

# Load Fashion-MNIST dataset
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# Normalize and reshape dataset
train_images = train_images.astype(np.float32) / 255.0  # Normalize to [0,1]
test_images = test_images.astype(np.float32) / 255.0

# Define Custom PyTorch Dataset
class FashionMNISTDataset(Dataset):
    def __init__(self, images, labels):
        self.images = images
        self.labels = labels

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = np.expand_dims(self.images[idx], axis=0)  # Add channel dimension (1, 28, 28)
        label = self.labels[idx]
        return torch.tensor(image, dtype=torch.float32), torch.tensor(label, dtype=torch.long)

# Create DataLoader
train_dataset = FashionMNISTDataset(train_images, train_labels)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)

# Define CNN Model
class FashionCNN(nn.Module):
    def __init__(self):
        super(FashionCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(32 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)
        self.pool = nn.MaxPool2d(2, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 32 * 7 * 7)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = FashionCNN().to(device)

# Feature Map Visualization
def visualize_feature_maps(model, image):
    image = image.unsqueeze(0).to(device)  # Add batch dimension
    fig, axes = plt.subplots(4, 4, figsize=(10, 10))
    model.eval()

    with torch.no_grad():
        x = model.conv1(image)
        x = F.relu(x)

    for i in range(16):
        ax = axes[i // 4, i % 4]
        ax.imshow(x[0, i].cpu().numpy(), cmap="gray")
        ax.axis("off")

    plt.show()

# Get one sample image
image, _ = train_dataset[0]
visualize_feature_maps(model, image)

# Training Setup
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train the model
num_epochs = 5
for epoch in range(num_epochs):
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}")

# Save the trained model
torch.save(model.state_dict(), "fashion_cnn.pth")
# Out:
# Epoch [1/5], Loss: 0.6553
# Epoch [2/5], Loss: 0.6116
# Epoch [3/5], Loss: 0.2889
# Epoch [4/5], Loss: 0.1596
# Epoch [5/5], Loss: 0.2720
